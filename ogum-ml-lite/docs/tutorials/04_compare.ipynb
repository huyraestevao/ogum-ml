# %% [markdown]
# # Tutorial 04 — Model comparison
#
# Compare benchmark runs and visualize leaderboards generated by the CLI.

# %%
from ogum_lite.ml_experiments import run_benchmark_matrix
from ogum_lite.ml_experiments import compare_models

summary = compare_models("artifacts/bench_cls/bench_results.csv")
summary.head()
